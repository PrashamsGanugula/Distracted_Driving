# %%
# Notebook: 1-Automated-Labeler.ipynb (Final Version with Original Colab Logic)

import os
import cv2
from PIL import Image
from transformers import pipeline
import torch
from moviepy.video.io.VideoFileClip import VideoFileClip
import gc

# --- CONFIGURATION ---
# IMPORTANT: UPDATE THIS PATH to your project folder on your computer.
BASE_DIR = "D:/Distracted_Driving_Detection_Project"

RAW_VIDEOS_DIR = os.path.join(BASE_DIR, "raw_videos")
OUTPUT_CLIPS_DIR = BASE_DIR

# --- USING THE ORIGINAL, MORE EFFECTIVE LABELS FROM THE COLAB SCRIPT ---
CANDIDATE_LABELS = [
    "a person driving normally looking forward",
    "a person looking to the left side",
    "a person looking to the right side",
    "a person looking down at a phone"
]
FOLDER_LABELS = ["Normal_Driving", "Looking_Left", "Looking_Right", "Using_Phone"]

# --- LOAD AI MODEL ---
print("🧠 Loading the Zero-Shot Classification model...")
device = 0 if torch.cuda.is_available() else -1
if device == 0:
    print("GPU detected! Model will run on the GPU for faster processing.")
else:
    print("No GPU detected. Model will run on the CPU (this will be slow).")

classifier = pipeline(
    "zero-shot-image-classification",
    model="openai/clip-vit-large-patch14",
    device=device
)
print("✅ AI Model loaded successfully.")

# --- PROCESSING LOGIC ---
FRAME_INTERVAL = 15
MIN_CLIP_DURATION_SECONDS = 2.0

video_files = [f for f in os.listdir(RAW_VIDEOS_DIR) if f.endswith(('.mp4', '.avi', '.mov'))]
print(f"\nFound {len(video_files)} videos to process.")

for video_filename in video_files:
    video_path = os.path.join(RAW_VIDEOS_DIR, video_filename)
    print(f"\n▶️ Processing video: {video_filename}")
    
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"  ❌ Error: Could not open video file.")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS) if cap.get(cv2.CAP_PROP_FPS) > 0 else 30
    min_frames_for_clip = int(fps * MIN_CLIP_DURATION_SECONDS)
    frame_predictions = []
    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret: break
        if frame_count % FRAME_INTERVAL == 0:
            try:
                pil_image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                outputs = classifier(pil_image, candidate_labels=CANDIDATE_LABELS)
                top_prediction = outputs[0]['label']
                frame_predictions.append(top_prediction)
                print(f"  Frame {frame_count}: Classified as '{top_prediction}'")
            except Exception as e:
                print(f"  ⚠️ Error classifying frame {frame_count}: {e}")
        frame_count += 1
    cap.release()
    
    if not frame_predictions:
        print("  ❌ No frames were classified for this video.")
        continue

    print(f"  ✅ Finished classifying frames. Now grouping actions and cutting clips...")
    current_action = frame_predictions[0]
    start_frame = 0
    clip_counter = 0

    for i in range(1, len(frame_predictions)):
        if frame_predictions[i] != current_action:
            end_frame = i * FRAME_INTERVAL
            segment_frame_count = end_frame - start_frame
            if segment_frame_count >= min_frames_for_clip:
                start_time = start_frame / fps
                end_time = end_frame / fps
                action_index = CANDIDATE_LABELS.index(current_action)
                folder_name = FOLDER_LABELS[action_index]
                output_folder = os.path.join(OUTPUT_CLIPS_DIR, folder_name)
                os.makedirs(output_folder, exist_ok=True)
                output_filename = f"{os.path.splitext(video_filename)[0]}_{folder_name}_{clip_counter}.mp4"
                output_path = os.path.join(output_folder, output_filename)
                print(f"    🎬 Cutting clip for '{folder_name}' ({start_time:.2f}s to {end_time:.2f}s)")
                try:
                    with VideoFileClip(video_path) as video_clip:
                        # Ensure end_time doesn't exceed video duration
                        safe_end_time = min(end_time, video_clip.duration)
                        if safe_end_time > start_time:
                            new_clip = video_clip.subclip(start_time, safe_end_time)
                            new_clip.write_videofile(output_path, codec="libx264", audio_codec="aac", logger=None)
                            clip_counter += 1
                except Exception as e:
                    print(f"      ⚠️ Error cutting clip: {e}")
            current_action = frame_predictions[i]
            start_frame = i * FRAME_INTERVAL

    # This block correctly processes the final clip
    start_time = start_frame / fps
    try:
        with VideoFileClip(video_path) as video_clip:
            end_time = video_clip.duration
            if (end_time - start_time) >= MIN_CLIP_DURATION_SECONDS:
                action_index = CANDIDATE_LABELS.index(current_action)
                folder_name = FOLDER_LABELS[action_index]
                output_folder = os.path.join(OUTPUT_CLIPS_DIR, folder_name)
                os.makedirs(output_folder, exist_ok=True)
                output_filename = f"{os.path.splitext(video_filename)[0]}_{folder_name}_{clip_counter}.mp4"
                output_path = os.path.join(output_folder, output_filename)
                print(f"    🎬 Cutting final clip for '{folder_name}' ({start_time:.2f}s to {end_time:.2f}s)")
                new_clip = video_clip.subclip(start_time, end_time)
                new_clip.write_videofile(output_path, codec="libx264", audio_codec="aac", logger=None)
                clip_counter += 1
    except Exception as e:
        print(f"      ⚠️ Error cutting final clip: {e}")

# Clean up memory
del classifier
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

print("\n\n🎉 All videos processed.")
# Out:
# 🧠 Loading the Zero-Shot Classification model...
# No GPU detected. Model will run on the CPU (this will be slow).
# WARNING:tensorflow:From C:\Users\prash\anaconda3\envs\driver_monitor\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cpu
# ✅ AI Model loaded successfully.
#
# Found 31 videos to process.
#
# ▶️ Processing video: VID20250610110247.mp4
#   Frame 0: Classified as 'a person looking to the right side'
#   Frame 15: Classified as 'a person driving normally looking forward'
#   Frame 30: Classified as 'a person looking to the right side'
#   Frame 45: Classified as 'a person looking to the right side'
#   Frame 60: Classified as 'a person looking to the right side'
#   Frame 75: Classified as 'a person looking to the right side'
#   Frame 90: Classified as 'a person looking to the right side'
#   Frame 105: Classified as 'a person looking to the right side'
#   Frame 120: Classified as 'a person looking to the right side'
#   Frame 135: Classified as 'a person looking to the right side'
#   Frame 150: Classified as 'a person looking to the right side'
#   Frame 165: Classified as 'a person looking to the right side'
#   Frame 180: Classified as 'a person looking to the right side'
#   Frame 195: Classified as 'a person looking to the right side'
#   Frame 210: Classified as 'a person looking to the right side'
#   Frame 225: Classified as 'a person looking to the right side'
#   Frame 240: Classified as 'a person looking to the right side'
#   Frame 255: Classified as 'a person looking to the right side'
#   Frame 270: Classified as 'a person looking to the right side'
#   Frame 285: Classified as 'a person looking to the right side'
#   Frame 300: Classified as 'a person looking to the right side'
#   Frame 315: Classified as 'a person looking to the right side'
#   Frame 330: Classified as 'a person looking to the right side'
#   Frame 345: Classified as 'a person looking to the right side'
#   Frame 360: Classified as 'a person looking to the right side'
#   Frame 375: Classified as 'a person looking to the right side'
#   Frame 390: Classified as 'a person looking to the right side'
#   Frame 405: Classified as 'a person looking to the right side'
#   Frame 420: Classified as 'a person looking to the right side'
#   Frame 435: Classified as 'a person looking to the right side'
#   Frame 450: Classified as 'a person looking to the right side'
#   Frame 465: Classified as 'a person looking to the right side'
#   Frame 480: Classified as 'a person looking to the right side'
#   Frame 495: Classified as 'a person looking to the right side'
#   Frame 510: Classified as 'a person looking to the right side'
#   Frame 525: Classified as 'a person looking to the right side'
#   Frame 540: Classified as 'a person looking to the right side'
#   Frame 555: Classified as 'a person looking to the right side'
#   Frame 570: Classified as 'a person driving normally looking forward'
#   Frame 585: Classified as 'a person looking to the right side'
#   Frame 600: Classified as 'a person looking to the right side'
#   Frame 615: Classified as 'a person looking to the right side'
#   Frame 630: Classified as 'a person looking to the right side'
#   Frame 645: Classified as 'a person looking to the right side'
#   Frame 660: Classified as 'a person looking to the right side'
#   Frame 675: Classified as 'a person looking to the right side'
#   Frame 690: Classified as 'a person looking to the right side'
#   Frame 705: Classified as 'a person looking to the right side'
#   Frame 720: Classified as 'a person looking to the right side'
#   Frame 735: Classified as 'a person looking to the right side'
#   Frame 750: Classified as 'a person looking to the right side'
#   Frame 765: Classified as 'a person looking to the right side'
#   Frame 780: Classified as 'a person looking to the right side'
#   Frame 795: Classified as 'a person looking to the left side'
#   Frame 810: Classified as 'a person looking to the right side'
#   Frame 825: Classified as 'a person looking to the right side'
#   Frame 840: Classified as 'a person driving normally looking forward'
#   Frame 855: Classified as 'a person driving normally looking forward'
#   Frame 870: Classified as 'a person driving normally looking forward'
#   Frame 885: Classified as 'a person looking to the right side'
#   Frame 900: Classified as 'a person looking to the right side'
#   Frame 915: Classified as 'a person looking to the right side'
#   Frame 930: Classified as 'a person driving normally looking forward'
#   Frame 945: Classified as 'a person looking to the right side'
#   Frame 960: Classified as 'a person looking to the right side'
#   Frame 975: Classified as 'a person looking to the right side'
#   Frame 990: Classified as 'a person looking to the right side'
#   Frame 1005: Classified as 'a person looking to the right side'
#   Frame 1020: Classified as 'a person looking to the right side'
#   Frame 1035: Classified as 'a person looking to the right side'
#   Frame 1050: Classified as 'a person looking to the right side'
#   Frame 1065: Classified as 'a person looking to the right side'
#   Frame 1080: Classified as 'a person looking to the right side'
#   Frame 1095: Classified as 'a person looking to the right side'
#   Frame 1110: Classified as 'a person looking to the right side'
#   Frame 1125: Classified as 'a person driving normally looking forward'
#   Frame 1140: Classified as 'a person looking to the right side'
#   Frame 1155: Classified as 'a person looking to the right side'
#   Frame 1170: Classified as 'a person looking to the right side'
#   Frame 1185: Classified as 'a person looking to the right side'
#   Frame 1200: Classified as 'a person looking to the right side'
#   Frame 1215: Classified as 'a person looking to the right side'
#   Frame 1230: Classified as 'a person looking to the right side'
#   Frame 1245: Classified as 'a person looking to the right side'
#   Frame 1260: Classified as 'a person looking to the right side'
#   Frame 1275: Classified as 'a person looking to the right side'
#   Frame 1290: Classified as 'a person looking to the right side'
#   Frame 1305: Classified as 'a person looking to the right side'
#   Frame 1320: Classified as 'a person looking to the right side'
#   Frame 1335: Classified as 'a person looking to the right side'
#   Frame 1350: Classified as 'a person looking to the right side'
#   Frame 1365: Classified as 'a person looking to the right side'
#   Frame 1380: Classified as 'a person driving normally looking forward'
#   Frame 1395: Classified as 'a person looking to the right side'
#   Frame 1410: Classified as 'a person driving normally looking forward'
#   Frame 1425: Classified as 'a person driving normally looking forward'
#   Frame 1440: Classified as 'a person looking to the right side'
#   Frame 1455: Classified as 'a person driving normally looking forward'
#   Frame 1470: Classified as 'a person looking to the right side'
#   Frame 1485: Classified as 'a person looking to the right side'
#   Frame 1500: Classified as 'a person looking to the right side'
#   Frame 1515: Classified as 'a person driving normally looking forward'
#   Frame 1530: Classified as 'a person looking to the right side'
#   Frame 1545: Classified as 'a person looking to the right side'
#   Frame 1560: Classified as 'a person driving normally looking forward'
#   Frame 1575: Classified as 'a person driving normally looking forward'
#   Frame 1590: Classified as 'a person looking to the right side'
#   Frame 1605: Classified as 'a person driving normally looking forward'
#   Frame 1620: Classified as 'a person looking to the right side'
#   Frame 1635: Classified as 'a person looking to the right side'
#   Frame 1650: Classified as 'a person driving normally looking forward'
#   Frame 1665: Classified as 'a person looking to the right side'
#   Frame 1680: Classified as 'a person looking to the right side'
#   Frame 1695: Classified as 'a person looking to the right side'
#   Frame 1710: Classified as 'a person looking to the right side'
#   Frame 1725: Classified as 'a person looking to the right side'
#   Frame 1740: Classified as 'a person looking to the right side'
#   Frame 1755: Classified as 'a person looking to the right side'
#   Frame 1770: Classified as 'a person looking to the right side'
#   Frame 1785: Classified as 'a person looking to the right side'
#   Frame 1800: Classified as 'a person looking to the right side'
#   Frame 1815: Classified as 'a person looking to the right side'
#   Frame 1830: Classified as 'a person looking to the right side'
#   Frame 1845: Classified as 'a person looking to the right side'
#   Frame 1860: Classified as 'a person looking to the right side'
#   Frame 1875: Classified as 'a person looking to the right side'
#   Frame 1890: Classified as 'a person looking to the right side'
#   Frame 1905: Classified as 'a person looking to the right side'
#   Frame 1920: Classified as 'a person looking to the right side'
#   Frame 1935: Classified as 'a person looking to the right side'
#   Frame 1950: Classified as 'a person driving normally looking forward'
#   Frame 1965: Classified as 'a person looking to the right side'
#   Frame 1980: Classified as 'a person looking to the right side'
#   Frame 1995: Classified as 'a person looking to the right side'
#   Frame 2010: Classified as 'a person looking to the right side'
#   Frame 2025: Classified as 'a person looking to the right side'
#   Frame 2040: Classified as 'a person driving normally looking forward'
#   Frame 2055: Classified as 'a person driving normally looking forward'
#   Frame 2070: Classified as 'a person driving normally looking forward'
#   Frame 2085: Classified as 'a person driving normally looking forward'
#   Frame 2100: Classified as 'a person looking to the right side'
#   Frame 2115: Classified as 'a person looking to the right side'
#   Frame 2130: Classified as 'a person looking to the right side'
#   Frame 2145: Classified as 'a person driving normally looking forward'
#   Frame 2160: Classified as 'a person driving normally looking forward'
#   Frame 2175: Classified as 'a person driving normally looking forward'
#   Frame 2190: Classified as 'a person looking to the right side'
#   Frame 2205: Classified as 'a person looking to the right side'
#   Frame 2220: Classified as 'a person looking to the left side'
#   Frame 2235: Classified as 'a person looking to the right side'
#   Frame 2250: Classified as 'a person looking to the right side'
#   Frame 2265: Classified as 'a person driving normally looking forward'
#   Frame 2280: Classified as 'a person driving normally looking forward'
#   Frame 2295: Classified as 'a person looking to the right side'
#   Frame 2310: Classified as 'a person looking to the right side'
#   Frame 2325: Classified as 'a person driving normally looking forward'
#   Frame 2340: Classified as 'a person looking to the right side'
#   Frame 2355: Classified as 'a person looking to the right side'
#   Frame 2370: Classified as 'a person looking to the right side'
#   Frame 2385: Classified as 'a person looking to the right side'
#   Frame 2400: Classified as 'a person looking to the right side'
#   Frame 2415: Classified as 'a person looking to the right side'
#   Frame 2430: Classified as 'a person looking to the right side'
#   Frame 2445: Classified as 'a person looking to the right side'
#   Frame 2460: Classified as 'a person looking to the right side'
#   Frame 2475: Classified as 'a person looking to the right side'
#   Frame 2490: Classified as 'a person driving normally looking forward'
#   Frame 2505: Classified as 'a person driving normally looking forward'
#   Frame 2520: Classified as 'a person looking to the right side'
#   Frame 2535: Classified as 'a person looking to the right side'
#   Frame 2550: Classified as 'a person looking to the right side'
#   Frame 2565: Classified as 'a person looking to the left side'
#   Frame 2580: Classified as 'a person looking to the right side'
#   Frame 2595: Classified as 'a person looking to the right side'
#   Frame 2610: Classified as 'a person looking to the right side'
#   Frame 2625: Classified as 'a person looking to the right side'
#   Frame 2640: Classified as 'a person looking to the right side'
#   Frame 2655: Classified as 'a person looking to the right side'
#   Frame 2670: Classified as 'a person looking to the right side'
#   Frame 2685: Classified as 'a person looking to the right side'
#   Frame 2700: Classified as 'a person looking to the right side'
#   Frame 2715: Classified as 'a person looking to the right side'
#   Frame 2730: Classified as 'a person looking to the right side'
#   Frame 2745: Classified as 'a person looking to the right side'
#   Frame 2760: Classified as 'a person looking to the left side'
#   Frame 2775: Classified as 'a person looking to the right side'
#   Frame 2790: Classified as 'a person looking to the right side'
#   Frame 2805: Classified as 'a person looking to the right side'
#   Frame 2820: Classified as 'a person looking to the left side'
#   Frame 2835: Classified as 'a person looking to the right side'
#   Frame 2850: Classified as 'a person driving normally looking forward'
#   Frame 2865: Classified as 'a person looking to the right side'
#   Frame 2880: Classified as 'a person driving normally looking forward'
#   Frame 2895: Classified as 'a person looking to the right side'
#   Frame 2910: Classified as 'a person driving normally looking forward'
#   Frame 2925: Classified as 'a person looking to the right side'
#   Frame 2940: Classified as 'a person looking to the right side'
#   Frame 2955: Classified as 'a person driving normally looking forward'
#   Frame 2970: Classified as 'a person looking to the right side'
#   Frame 2985: Classified as 'a person looking to the right side'
#   Frame 3000: Classified as 'a person looking to the right side'
#   Frame 3015: Classified as 'a person looking to the right side'
#   Frame 3030: Classified as 'a person looking to the right side'
#   Frame 3045: Classified as 'a person looking to the right side'
#   Frame 3060: Classified as 'a person looking to the right side'
#   Frame 3075: Classified as 'a person looking to the right side'
#   Frame 3090: Classified as 'a person looking to the right side'
#   Frame 3105: Classified as 'a person looking to the right side'
#   Frame 3120: Classified as 'a person looking to the right side'
#   Frame 3135: Classified as 'a person looking to the left side'
#   Frame 3150: Classified as 'a person looking to the right side'
#   Frame 3165: Classified as 'a person looking to the left side'
#   Frame 3180: Classified as 'a person looking to the right side'
#   Frame 3195: Classified as 'a person looking to the right side'
#   Frame 3210: Classified as 'a person looking to the right side'
#   Frame 3225: Classified as 'a person driving normally looking forward'
#   Frame 3240: Classified as 'a person looking to the right side'
#   Frame 3255: Classified as 'a person driving normally looking forward'
#   Frame 3270: Classified as 'a person looking to the right side'
#   Frame 3285: Classified as 'a person driving normally looking forward'
#   Frame 3300: Classified as 'a person looking to the right side'
#   Frame 3315: Classified as 'a person looking to the right side'
#   Frame 3330: Classified as 'a person looking to the right side'
#   Frame 3345: Classified as 'a person driving normally looking forward'
#   Frame 3360: Classified as 'a person looking to the left side'
#   Frame 3375: Classified as 'a person looking to the right side'
#   Frame 3390: Classified as 'a person driving normally looking forward'
#   Frame 3405: Classified as 'a person looking to the right side'
#   Frame 3420: Classified as 'a person looking to the right side'
#   Frame 3435: Classified as 'a person looking to the right side'
#   Frame 3450: Classified as 'a person looking to the left side'
#   Frame 3465: Classified as 'a person driving normally looking forward'
#   Frame 3480: Classified as 'a person driving normally looking forward'
#   Frame 3495: Classified as 'a person looking to the right side'
#   Frame 3510: Classified as 'a person looking to the left side'
#   Frame 3525: Classified as 'a person driving normally looking forward'
#   Frame 3540: Classified as 'a person looking to the right side'
#   Frame 3555: Classified as 'a person looking to the right side'
#   Frame 3570: Classified as 'a person looking to the right side'
#   Frame 3585: Classified as 'a person looking to the right side'
#   Frame 3600: Classified as 'a person looking to the right side'
#   Frame 3615: Classified as 'a person looking to the right side'
#   Frame 3630: Classified as 'a person looking to the right side'
#   Frame 3645: Classified as 'a person looking to the right side'
#   Frame 3660: Classified as 'a person looking to the right side'
#   Frame 3675: Classified as 'a person looking to the right side'
#   Frame 3690: Classified as 'a person looking to the right side'
#   Frame 3705: Classified as 'a person looking to the right side'
#   Frame 3720: Classified as 'a person looking to the right side'
#   Frame 3735: Classified as 'a person looking to the right side'
#   Frame 3750: Classified as 'a person looking to the right side'
#   Frame 3765: Classified as 'a person looking to the right side'
#   Frame 3780: Classified as 'a person looking to the right side'
#   Frame 3795: Classified as 'a person looking to the right side'
#   Frame 3810: Classified as 'a person looking to the right side'
#   Frame 3825: Classified as 'a person looking to the right side'
#   Frame 3840: Classified as 'a person looking to the right side'
#   Frame 3855: Classified as 'a person looking to the right side'
#   Frame 3870: Classified as 'a person looking to the right side'
#   Frame 3885: Classified as 'a person looking to the right side'
#   Frame 3900: Classified as 'a person looking to the right side'
#   Frame 3915: Classified as 'a person looking to the right side'
#   Frame 3930: Classified as 'a person looking to the right side'
#   Frame 3945: Classified as 'a person looking to the right side'
#   Frame 3960: Classified as 'a person looking to the right side'
#   Frame 3975: Classified as 'a person looking to the right side'
#   Frame 3990: Classified as 'a person looking to the right side'
#   Frame 4005: Classified as 'a person looking to the right side'
#   Frame 4020: Classified as 'a person driving normally looking forward'
#   Frame 4035: Classified as 'a person driving normally looking forward'
#   Frame 4050: Classified as 'a person looking to the right side'
#   Frame 4065: Classified as 'a person looking to the right side'
#   Frame 4080: Classified as 'a person looking to the right side'
#   Frame 4095: Classified as 'a person looking to the right side'
#   Frame 4110: Classified as 'a person looking to the right side'
#   Frame 4125: Classified as 'a person looking to the right side'
#   Frame 4140: Classified as 'a person looking to the right side'
#   Frame 4155: Classified as 'a person looking to the right side'
#   Frame 4170: Classified as 'a person looking to the right side'
#   Frame 4185: Classified as 'a person looking to the right side'
#   Frame 4200: Classified as 'a person looking to the right side'
#   Frame 4215: Classified as 'a person looking to the right side'
#   Frame 4230: Classified as 'a person looking to the left side'
#   Frame 4245: Classified as 'a person looking to the right side'
#   ✅ Finished classifying frames. Now grouping actions and cutting clips...
#     🎬 Cutting clip for 'Looking_Right' (1.00s to 19.05s)
#     🎬 Cutting clip for 'Looking_Right' (19.55s to 26.57s)
#     🎬 Cutting clip for 'Looking_Right' (31.58s to 37.59s)
#     🎬 Cutting clip for 'Looking_Right' (38.10s to 46.12s)
#     🎬 Cutting clip for 'Looking_Right' (55.64s to 65.16s)
#     🎬 Cutting clip for 'Looking_Right' (65.67s to 68.17s)
#     🎬 Cutting clip for 'Normal_Driving' (68.17s to 70.18s)
#     🎬 Cutting clip for 'Looking_Right' (78.20s to 83.21s)
#     🎬 Cutting clip for 'Looking_Right' (86.22s to 92.23s)
#     🎬 Cutting clip for 'Looking_Right' (99.25s to 104.76s)
#     🎬 Cutting clip for 'Looking_Right' (118.30s to 134.34s)
#     🎬 Cutting clip for 'Looking_Right' (135.34s to 141.36s)
#
# ▶️ Processing video: VID20250610110528.mp4
#   Frame 0: Classified as 'a person looking to the right side'
#   Frame 15: Classified as 'a person looking to the right side'
#   Frame 30: Classified as 'a person looking to the right side'
#   Frame 45: Classified as 'a person looking to the right side'
#   Frame 60: Classified as 'a person looking to the right side'
#   Frame 75: Classified as 'a person looking to the right side'
#   Frame 90: Classified as 'a person looking to the right side'
#   Frame 105: Classified as 'a person looking to the right side'
#   Frame 120: Classified as 'a person looking to the right side'
#   Frame 135: Classified as 'a person looking to the right side'
#   Frame 150: Classified as 'a person driving normally looking forward'
#   Frame 165: Classified as 'a person looking to the right side'
#   Frame 180: Classified as 'a person looking to the right side'
#   Frame 195: Classified as 'a person looking to the left side'
#   Frame 210: Classified as 'a person looking to the right side'
#   Frame 225: Classified as 'a person driving normally looking forward'
#   Frame 240: Classified as 'a person driving normally looking forward'
#   Frame 255: Classified as 'a person driving normally looking forward'
#   Frame 270: Classified as 'a person driving normally looking forward'
#   Frame 285: Classified as 'a person looking to the right side'
#   Frame 300: Classified as 'a person looking to the right side'
#   Frame 315: Classified as 'a person looking to the right side'
#   Frame 330: Classified as 'a person looking to the right side'
#   Frame 345: Classified as 'a person looking to the right side'
#   Frame 360: Classified as 'a person looking to the right side'
#   Frame 375: Classified as 'a person looking to the right side'
#   Frame 390: Classified as 'a person looking to the right side'
#   Frame 405: Classified as 'a person looking to the right side'
#   Frame 420: Classified as 'a person driving normally looking forward'
#   Frame 435: Classified as 'a person looking to the right side'
#   Frame 450: Classified as 'a person looking to the right side'
#   Frame 465: Classified as 'a person driving normally looking forward'
#   Frame 480: Classified as 'a person looking to the right side'
#   Frame 495: Classified as 'a person looking to the right side'
#   Frame 510: Classified as 'a person looking to the right side'
#   Frame 525: Classified as 'a person looking to the right side'
#   Frame 540: Classified as 'a person looking to the right side'
#   Frame 555: Classified as 'a person looking to the right side'
#   Frame 570: Classified as 'a person looking to the right side'
#   Frame 585: Classified as 'a person looking to the right side'
#   Frame 600: Classified as 'a person looking to the right side'
#   Frame 615: Classified as 'a person driving normally looking forward'
#   Frame 630: Classified as 'a person looking to the right side'
#   Frame 645: Classified as 'a person looking to the right side'
#   Frame 660: Classified as 'a person looking to the left side'
#   Frame 675: Classified as 'a person looking to the right side'
#   Frame 690: Classified as 'a person looking to the right side'
#   Frame 705: Classified as 'a person driving normally looking forward'
#   Frame 720: Classified as 'a person looking to the right side'
#   Frame 735: Classified as 'a person looking to the right side'
#   Frame 750: Classified as 'a person looking to the right side'
#   Frame 765: Classified as 'a person looking to the right side'
#   Frame 780: Classified as 'a person looking to the right side'
#   Frame 795: Classified as 'a person looking to the right side'
#   Frame 810: Classified as 'a person looking to the right side'
#   Frame 825: Classified as 'a person driving normally looking forward'
#   Frame 840: Classified as 'a person looking to the right side'
#   Frame 855: Classified as 'a person looking to the right side'
#   Frame 870: Classified as 'a person looking to the right side'
#   Frame 885: Classified as 'a person looking to the right side'
#   Frame 900: Classified as 'a person looking to the right side'
#   Frame 915: Classified as 'a person looking to the right side'
#   Frame 930: Classified as 'a person looking to the right side'
#   Frame 945: Classified as 'a person looking to the right side'
#   Frame 960: Classified as 'a person looking to the right side'
#   Frame 975: Classified as 'a person looking to the right side'
#   Frame 990: Classified as 'a person looking to the right side'
#   Frame 1005: Classified as 'a person looking to the right side'
#   Frame 1020: Classified as 'a person looking to the right side'
#   Frame 1035: Classified as 'a person looking to the right side'
#   Frame 1050: Classified as 'a person looking to the right side'
#   Frame 1065: Classified as 'a person looking to the right side'
#   Frame 1080: Classified as 'a person driving normally looking forward'
#   Frame 1095: Classified as 'a person looking to the right side'
#   Frame 1110: Classified as 'a person looking to the right side'
#   Frame 1125: Classified as 'a person looking to the right side'
#   Frame 1140: Classified as 'a person looking to the right side'
#   Frame 1155: Classified as 'a person looking to the right side'
#   Frame 1170: Classified as 'a person driving normally looking forward'
#   Frame 1185: Classified as 'a person looking to the right side'
#   Frame 1200: Classified as 'a person looking to the right side'
#   Frame 1215: Classified as 'a person looking to the right side'
#   Frame 1230: Classified as 'a person driving normally looking forward'
#   Frame 1245: Classified as 'a person looking to the right side'
#   Frame 1260: Classified as 'a person driving normally looking forward'
#   Frame 1275: Classified as 'a person looking to the right side'
#   Frame 1290: Classified as 'a person looking to the right side'
#   Frame 1305: Classified as 'a person looking to the right side'
#   Frame 1320: Classified as 'a person looking to the right side'
#   Frame 1335: Classified as 'a person looking to the right side'
#   Frame 1350: Classified as 'a person looking to the right side'
#   Frame 1365: Classified as 'a person looking to the right side'
#   Frame 1380: Classified as 'a person looking to the right side'
#   Frame 1395: Classified as 'a person driving normally looking forward'
#   Frame 1410: Classified as 'a person looking to the right side'
#   Frame 1425: Classified as 'a person looking to the right side'
#   Frame 1440: Classified as 'a person looking to the right side'
#   Frame 1455: Classified as 'a person looking to the right side'
#   Frame 1470: Classified as 'a person looking to the right side'
#   Frame 1485: Classified as 'a person driving normally looking forward'
#   Frame 1500: Classified as 'a person looking to the right side'
#   Frame 1515: Classified as 'a person looking to the right side'
#   Frame 1530: Classified as 'a person looking to the left side'
#   Frame 1545: Classified as 'a person looking to the right side'
#   Frame 1560: Classified as 'a person looking to the right side'
#   Frame 1575: Classified as 'a person looking to the right side'
#   Frame 1590: Classified as 'a person looking to the right side'
#   Frame 1605: Classified as 'a person looking to the right side'
#   Frame 1620: Classified as 'a person driving normally looking forward'
#   Frame 1635: Classified as 'a person looking to the left side'
#   Frame 1650: Classified as 'a person looking to the right side'
#   Frame 1665: Classified as 'a person looking to the right side'
#   Frame 1680: Classified as 'a person looking to the right side'
#   Frame 1695: Classified as 'a person looking to the right side'
#   Frame 1710: Classified as 'a person looking to the right side'
#   Frame 1725: Classified as 'a person looking to the right side'
#   Frame 1740: Classified as 'a person looking to the right side'
#   Frame 1755: Classified as 'a person looking to the right side'
#   Frame 1770: Classified as 'a person looking to the right side'
#   Frame 1785: Classified as 'a person looking to the right side'
#   Frame 1800: Classified as 'a person looking to the right side'
#   Frame 1815: Classified as 'a person driving normally looking forward'
#   Frame 1830: Classified as 'a person looking to the right side'
#   Frame 1845: Classified as 'a person looking to the right side'
#   Frame 1860: Classified as 'a person looking to the right side'
#   Frame 1875: Classified as 'a person looking to the right side'
#   Frame 1890: Classified as 'a person looking to the right side'
#   Frame 1905: Classified as 'a person looking to the right side'
#   Frame 1920: Classified as 'a person looking to the right side'
#   Frame 1935: Classified as 'a person looking to the right side'
#   Frame 1950: Classified as 'a person looking to the right side'
#   Frame 1965: Classified as 'a person driving normally looking forward'
#   Frame 1980: Classified as 'a person looking to the right side'
#   Frame 1995: Classified as 'a person looking to the right side'
#   Frame 2010: Classified as 'a person looking to the right side'
#   Frame 2025: Classified as 'a person looking to the right side'
#   Frame 2040: Classified as 'a person looking to the right side'
#   Frame 2055: Classified as 'a person looking to the left side'
#   Frame 2070: Classified as 'a person driving normally looking forward'
#   Frame 2085: Classified as 'a person looking to the right side'
#   Frame 2100: Classified as 'a person looking to the right side'
#   Frame 2115: Classified as 'a person looking to the right side'
#   Frame 2130: Classified as 'a person looking to the right side'
#   Frame 2145: Classified as 'a person looking to the right side'
#   Frame 2160: Classified as 'a person driving normally looking forward'
#   Frame 2175: Classified as 'a person looking to the right side'
#   Frame 2190: Classified as 'a person looking to the right side'
#   Frame 2205: Classified as 'a person driving normally looking forward'
#   Frame 2220: Classified as 'a person looking to the right side'
#   Frame 2235: Classified as 'a person looking to the right side'
#   Frame 2250: Classified as 'a person looking to the right side'
#   Frame 2265: Classified as 'a person looking to the right side'
#   Frame 2280: Classified as 'a person looking to the right side'
#   Frame 2295: Classified as 'a person looking to the right side'
#   Frame 2310: Classified as 'a person looking to the right side'
#   Frame 2325: Classified as 'a person looking to the left side'
#   Frame 2340: Classified as 'a person looking to the right side'
#   Frame 2355: Classified as 'a person driving normally looking forward'
#   Frame 2370: Classified as 'a person looking to the right side'
#   Frame 2385: Classified as 'a person looking to the right side'
#   Frame 2400: Classified as 'a person looking to the right side'
#   Frame 2415: Classified as 'a person looking to the right side'
#   Frame 2430: Classified as 'a person driving normally looking forward'
#   Frame 2445: Classified as 'a person looking to the right side'
#   Frame 2460: Classified as 'a person looking to the right side'
#   Frame 2475: Classified as 'a person looking to the right side'
#   Frame 2490: Classified as 'a person looking to the right side'
#   Frame 2505: Classified as 'a person looking to the right side'
#   Frame 2520: Classified as 'a person looking to the right side'
#   Frame 2535: Classified as 'a person looking to the right side'
#   Frame 2550: Classified as 'a person looking to the right side'
#   Frame 2565: Classified as 'a person looking to the right side'
#   Frame 2580: Classified as 'a person driving normally looking forward'
#   Frame 2595: Classified as 'a person looking to the right side'
#   Frame 2610: Classified as 'a person looking to the right side'
#   Frame 2625: Classified as 'a person looking to the right side'
#   Frame 2640: Classified as 'a person looking to the right side'
#   Frame 2655: Classified as 'a person looking to the right side'
#   Frame 2670: Classified as 'a person looking to the right side'
#   Frame 2685: Classified as 'a person looking to the right side'
#   Frame 2700: Classified as 'a person looking to the right side'
#   Frame 2715: Classified as 'a person looking to the right side'
#   Frame 2730: Classified as 'a person looking to the right side'
#   Frame 2745: Classified as 'a person looking to the right side'
#   Frame 2760: Classified as 'a person looking to the right side'
#   Frame 2775: Classified as 'a person looking to the right side'
#   Frame 2790: Classified as 'a person looking to the right side'
#   Frame 2805: Classified as 'a person looking to the right side'
#   Frame 2820: Classified as 'a person looking to the right side'
#   Frame 2835: Classified as 'a person looking to the right side'
#   Frame 2850: Classified as 'a person looking to the right side'
#   Frame 2865: Classified as 'a person looking to the right side'
#   Frame 2880: Classified as 'a person looking to the right side'
#   Frame 2895: Classified as 'a person looking to the right side'
#   Frame 2910: Classified as 'a person driving normally looking forward'
#   Frame 2925: Classified as 'a person looking to the right side'
#   Frame 2940: Classified as 'a person looking to the right side'
#   Frame 2955: Classified as 'a person looking to the right side'
#   Frame 2970: Classified as 'a person looking to the right side'
#   Frame 2985: Classified as 'a person looking to the right side'
#   Frame 3000: Classified as 'a person looking to the right side'
#   Frame 3015: Classified as 'a person looking to the right side'
#   Frame 3030: Classified as 'a person looking to the right side'
#   Frame 3045: Classified as 'a person looking to the right side'
#   Frame 3060: Classified as 'a person looking to the right side'
#   Frame 3075: Classified as 'a person looking to the right side'
#   Frame 3090: Classified as 'a person looking to the right side'
#   Frame 3105: Classified as 'a person looking to the right side'
#   Frame 3120: Classified as 'a person looking to the right side'
#   Frame 3135: Classified as 'a person looking to the right side'
#   Frame 3150: Classified as 'a person looking to the right side'
#   Frame 3165: Classified as 'a person looking to the right side'
#   Frame 3180: Classified as 'a person looking to the right side'
#   Frame 3195: Classified as 'a person looking to the right side'
#   Frame 3210: Classified as 'a person looking to the right side'
#   Frame 3225: Classified as 'a person looking to the right side'
#   Frame 3240: Classified as 'a person looking to the right side'
#   Frame 3255: Classified as 'a person looking to the right side'
#   Frame 3270: Classified as 'a person looking to the right side'
#   Frame 3285: Classified as 'a person looking to the right side'
#   Frame 3300: Classified as 'a person looking to the right side'
#   Frame 3315: Classified as 'a person driving normally looking forward'
#   Frame 3330: Classified as 'a person looking to the right side'
#   Frame 3345: Classified as 'a person looking to the right side'
#   Frame 3360: Classified as 'a person looking to the right side'
#   Frame 3375: Classified as 'a person looking to the right side'
#   Frame 3390: Classified as 'a person looking to the right side'
#   Frame 3405: Classified as 'a person looking to the right side'
#   Frame 3420: Classified as 'a person looking to the right side'
#   Frame 3435: Classified as 'a person looking to the right side'
#   Frame 3450: Classified as 'a person looking to the right side'
#   Frame 3465: Classified as 'a person looking to the right side'
#   Frame 3480: Classified as 'a person looking to the right side'
#   Frame 3495: Classified as 'a person looking to the right side'
#   ✅ Finished classifying frames. Now grouping actions and cutting clips...
#     🎬 Cutting clip for 'Looking_Right' (0.00s to 5.03s)
#     🎬 Cutting clip for 'Normal_Driving' (7.54s to 9.56s)
#     🎬 Cutting clip for 'Looking_Right' (9.56s to 14.08s)
#     🎬 Cutting clip for 'Looking_Right' (16.10s to 20.62s)
#     🎬 Cutting clip for 'Looking_Right' (24.14s to 27.66s)
#     🎬 Cutting clip for 'Looking_Right' (28.17s to 36.22s)
#     🎬 Cutting clip for 'Looking_Right' (36.72s to 39.23s)
#     🎬 Cutting clip for 'Looking_Right' (42.75s to 46.78s)
#     🎬 Cutting clip for 'Looking_Right' (47.28s to 49.80s)
#     🎬 Cutting clip for 'Looking_Right' (51.81s to 54.32s)
#     🎬 Cutting clip for 'Looking_Right' (55.33s to 60.86s)
#     🎬 Cutting clip for 'Looking_Right' (61.36s to 65.89s)
#     🎬 Cutting clip for 'Looking_Right' (66.39s to 68.91s)
#     🎬 Cutting clip for 'Looking_Right' (69.92s to 72.43s)
#     🎬 Cutting clip for 'Looking_Right' (74.44s to 77.96s)
#     🎬 Cutting clip for 'Looking_Right' (79.47s to 81.48s)
#     🎬 Cutting clip for 'Looking_Right' (81.99s to 86.51s)
#     🎬 Cutting clip for 'Looking_Right' (87.02s to 97.58s)
#     🎬 Cutting clip for 'Looking_Right' (98.08s to 111.16s)
#     🎬 Cutting final clip for 'Looking_Right' (111.66s to 117.41s)
#
# ▶️ Processing video: VID20250610111046.mp4
#   Frame 0: Classified as 'a person looking to the right side'
#   Frame 15: Classified as 'a person looking to the right side'
#   Frame 30: Classified as 'a person looking to the right side'
#   Frame 45: Classified as 'a person looking to the right side'
#   Frame 60: Classified as 'a person looking to the right side'
#   Frame 75: Classified as 'a person looking to the right side'
#   Frame 90: Classified as 'a person looking to the right side'
#   Frame 105: Classified as 'a person looking to the right side'
#   Frame 120: Classified as 'a person looking to the right side'
#   Frame 135: Classified as 'a person looking to the right side'
#   Frame 150: Classified as 'a person looking to the right side'
#   Frame 165: Classified as 'a person looking to the right side'
#   Frame 180: Classified as 'a person looking to the right side'
#   Frame 195: Classified as 'a person looking to the right side'
#   Frame 210: Classified as 'a person looking to the right side'
#   Frame 225: Classified as 'a person looking to the right side'
#   Frame 240: Classified as 'a person looking to the right side'
#   Frame 255: Classified as 'a person looking to the right side'
#   Frame 270: Classified as 'a person looking to the right side'
#   Frame 285: Classified as 'a person looking to the right side'
#   Frame 300: Classified as 'a person looking to the right side'
#   Frame 315: Classified as 'a person looking to the right side'
#   Frame 330: Classified as 'a person looking to the right side'
#   Frame 345: Classified as 'a person looking to the right side'
#   Frame 360: Classified as 'a person looking to the right side'
#   Frame 375: Classified as 'a person looking to the right side'
#   Frame 390: Classified as 'a person looking to the right side'
#   Frame 405: Classified as 'a person looking to the right side'
#   Frame 420: Classified as 'a person looking to the right side'
#   Frame 435: Classified as 'a person looking to the right side'
#   Frame 450: Classified as 'a person looking to the right side'
#   Frame 465: Classified as 'a person looking to the right side'
#   Frame 480: Classified as 'a person looking to the right side'
#   Frame 495: Classified as 'a person looking to the right side'
#   Frame 510: Classified as 'a person looking to the right side'
#   Frame 525: Classified as 'a person looking to the right side'
#   Frame 540: Classified as 'a person looking to the right side'
#   Frame 555: Classified as 'a person looking to the right side'
#   Frame 570: Classified as 'a person looking to the right side'
#   Frame 585: Classified as 'a person looking to the right side'
#   Frame 600: Classified as 'a person looking to the right side'
#   Frame 615: Classified as 'a person looking to the right side'
#   Frame 630: Classified as 'a person looking to the right side'
#   Frame 645: Classified as 'a person looking to the right side'
#   Frame 660: Classified as 'a person looking to the right side'
#   Frame 675: Classified as 'a person looking to the right side'
#   Frame 690: Classified as 'a person looking to the right side'
#   Frame 705: Classified as 'a person looking to the right side'
#   Frame 720: Classified as 'a person looking to the right side'
#   Frame 735: Classified as 'a person looking to the right side'
#   Frame 750: Classified as 'a person looking to the right side'
#   Frame 765: Classified as 'a person looking to the right side'
#   Frame 780: Classified as 'a person looking to the right side'
#   Frame 795: Classified as 'a person looking to the right side'
#   Frame 810: Classified as 'a person looking to the right side'
#   Frame 825: Classified as 'a person looking to the right side'
#   Frame 840: Classified as 'a person looking to the right side'
#   Frame 855: Classified as 'a person looking to the right side'
#   Frame 870: Classified as 'a person looking to the right side'
#   Frame 885: Classified as 'a person looking to the right side'
#   Frame 900: Classified as 'a person looking to the right side'
#   Frame 915: Classified as 'a person looking to the right side'
#   Frame 930: Classified as 'a person looking to the right side'
#   Frame 945: Classified as 'a person looking to the right side'
#   Frame 960: Classified as 'a person looking to the right side'
#   Frame 975: Classified as 'a person looking to the right side'
#   Frame 990: Classified as 'a person looking to the right side'
#   Frame 1005: Classified as 'a person looking to the right side'
#   Frame 1020: Classified as 'a person looking to the right side'
#   Frame 1035: Classified as 'a person looking to the right side'
#   Frame 1050: Classified as 'a person looking to the right side'
#   Frame 1065: Classified as 'a person looking to the right side'
#   Frame 1080: Classified as 'a person looking to the right side'
#   Frame 1095: Classified as 'a person looking to the right side'
#   Frame 1110: Classified as 'a person looking to the right side'
#   Frame 1125: Classified as 'a person looking to the right side'
#   Frame 1140: Classified as 'a person driving normally looking forward'
#   Frame 1155: Classified as 'a person looking to the right side'
#   Frame 1170: Classified as 'a person looking to the right side'
#   Frame 1185: Classified as 'a person looking to the right side'
#   Frame 1200: Classified as 'a person looking to the right side'
#   Frame 1215: Classified as 'a person looking to the right side'
#   Frame 1230: Classified as 'a person looking to the right side'
#   Frame 1245: Classified as 'a person looking to the right side'
#   Frame 1260: Classified as 'a person looking to the right side'
#   Frame 1275: Classified as 'a person looking to the right side'
#   Frame 1290: Classified as 'a person looking to the right side'
#   Frame 1305: Classified as 'a person looking to the right side'
#   Frame 1320: Classified as 'a person driving normally looking forward'
#   Frame 1335: Classified as 'a person looking to the right side'
#   Frame 1350: Classified as 'a person looking to the right side'
#   Frame 1365: Classified as 'a person looking to the right side'
#   Frame 1380: Classified as 'a person looking to the right side'
#   Frame 1395: Classified as 'a person looking to the right side'
#   Frame 1410: Classified as 'a person looking to the right side'
#   Frame 1425: Classified as 'a person looking to the right side'
#   Frame 1440: Classified as 'a person looking to the right side'
#   Frame 1455: Classified as 'a person looking to the right side'
#   Frame 1470: Classified as 'a person looking to the right side'
#   Frame 1485: Classified as 'a person looking to the right side'
#   Frame 1500: Classified as 'a person looking to the right side'
#   Frame 1515: Classified as 'a person looking to the right side'
#   Frame 1530: Classified as 'a person looking to the right side'
#   Frame 1545: Classified as 'a person looking to the right side'
#   Frame 1560: Classified as 'a person looking to the right side'
#   Frame 1575: Classified as 'a person looking to the right side'
#   Frame 1590: Classified as 'a person looking to the right side'
#   Frame 1605: Classified as 'a person looking to the right side'
#   Frame 1620: Classified as 'a person looking to the right side'
#   Frame 1635: Classified as 'a person looking to the right side'
#   Frame 1650: Classified as 'a person looking to the right side'
#   Frame 1665: Classified as 'a person looking to the right side'
#   Frame 1680: Classified as 'a person looking to the right side'
#   Frame 1695: Classified as 'a person looking to the right side'
#   Frame 1710: Classified as 'a person looking to the right side'
#   Frame 1725: Classified as 'a person looking to the right side'
#   Frame 1740: Classified as 'a person looking to the right side'
#   Frame 1755: Classified as 'a person looking to the right side'
#   Frame 1770: Classified as 'a person looking to the right side'
#   Frame 1785: Classified as 'a person looking to the right side'
#   Frame 1800: Classified as 'a person driving normally looking forward'
#   Frame 1815: Classified as 'a person looking to the right side'
#   Frame 1830: Classified as 'a person looking to the right side'
#   Frame 1845: Classified as 'a person looking to the right side'
#   Frame 1860: Classified as 'a person looking to the right side'
#   Frame 1875: Classified as 'a person looking to the right side'
#   Frame 1890: Classified as 'a person looking to the right side'
#   Frame 1905: Classified as 'a person looking to the right side'
#   Frame 1920: Classified as 'a person looking to the right side'
#   Frame 1935: Classified as 'a person looking to the right side'
#   Frame 1950: Classified as 'a person looking to the right side'
#   ✅ Finished classifying frames. Now grouping actions and cutting clips...
#     🎬 Cutting clip for 'Looking_Right' (0.00s to 38.93s)
#     🎬 Cutting clip for 'Looking_Right' (39.44s to 45.08s)
#     🎬 Cutting clip for 'Looking_Right' (45.59s to 61.47s)
#     🎬 Cutting final clip for 'Looking_Right' (61.98s to 66.96s)
#
# ▶️ Processing video: VID20250610111200.mp4
#   Frame 0: Classified as 'a person looking to the right side'
#   Frame 15: Classified as 'a person looking to the right side'
#   Frame 30: Classified as 'a person looking to the right side'
#   Frame 45: Classified as 'a person looking to the right side'
#   Frame 60: Classified as 'a person looking to the right side'
#   Frame 75: Classified as 'a person looking to the right side'
#   Frame 90: Classified as 'a person looking to the right side'
#   Frame 105: Classified as 'a person looking to the right side'
#   Frame 120: Classified as 'a person driving normally looking forward'
#   Frame 135: Classified as 'a person looking to the right side'
#   Frame 150: Classified as 'a person driving normally looking forward'
#   Frame 165: Classified as 'a person looking to the right side'
#   Frame 180: Classified as 'a person looking to the right side'
#   Frame 195: Classified as 'a person looking to the right side'
#   Frame 210: Classified as 'a person looking to the right side'
#   Frame 225: Classified as 'a person looking to the right side'
#   Frame 240: Classified as 'a person looking to the right side'
#   Frame 255: Classified as 'a person looking to the right side'
#   Frame 270: Classified as 'a person looking to the right side'
#   Frame 285: Classified as 'a person looking to the right side'
#   Frame 300: Classified as 'a person looking to the right side'
#   Frame 315: Classified as 'a person looking to the right side'
#   Frame 330: Classified as 'a person looking to the right side'
#   Frame 345: Classified as 'a person looking to the right side'
#   Frame 360: Classified as 'a person looking to the right side'
#   Frame 375: Classified as 'a person looking to the right side'
#   Frame 390: Classified as 'a person looking to the right side'
#   Frame 405: Classified as 'a person looking to the right side'
#   Frame 420: Classified as 'a person looking to the right side'
#   Frame 435: Classified as 'a person looking to the right side'
#   Frame 450: Classified as 'a person looking to the right side'
#   Frame 465: Classified as 'a person looking to the right side'
#   Frame 480: Classified as 'a person looking to the right side'
#   Frame 495: Classified as 'a person looking to the right side'
# ...
#   Frame 990: Classified as 'a person looking to the right side'
#   Frame 1005: Classified as 'a person looking to the right side'
#   Frame 1020: Classified as 'a person looking to the right side'
#   Frame 1035: Classified as 'a person looking to the right side'
#   Frame 1050: Classified as 'a person looking to the right side'
#   Frame 1065: Classified as 'a person looking to the right side'
#   Frame 1080: Classified as 'a person looking to the right side'
#   Frame 1095: Classified as 'a person looking to the right side'
#   Frame 1110: Classified as 'a person looking to the right side'
#   Frame 1125: Classified as 'a person looking to the right side'
#   Frame 1140: Classified as 'a person looking to the right side'
#   Frame 1155: Classified as 'a person looking to the right side'
#   Frame 1170: Classified as 'a person looking to the right side'
#   Frame 1185: Classified as 'a person driving normally looking forward'
#   Frame 1200: Classified as 'a person looking to the right side'
#   Frame 1215: Classified as 'a person looking to the right side'
#   Frame 1230: Classified as 'a person looking to the right side'
#   Frame 1245: Classified as 'a person looking to the right side'
#   Frame 1260: Classified as 'a person looking to the right side'
#   Frame 1275: Classified as 'a person looking to the right side'
#   Frame 1290: Classified as 'a person looking to the right side'
#   Frame 1305: Classified as 'a person looking to the right side'
#   Frame 1320: Classified as 'a person looking to the right side'
#   Frame 1335: Classified as 'a person looking to the right side'
#   Frame 1350: Classified as 'a person looking to the right side'
#   Frame 1365: Classified as 'a person looking to the right side'
#   Frame 1380: Classified as 'a person looking to the right side'
#   Frame 1395: Classified as 'a person looking to the right side'
#   Frame 1410: Classified as 'a person looking to the right side'
#   Frame 1425: Classified as 'a person looking to the right side'
#   Frame 1440: Classified as 'a person looking to the right side'
#   Frame 1455: Classified as 'a person looking to the right side'
#   Frame 1470: Classified as 'a person looking to the right side'
#   Frame 1485: Classified as 'a person looking to the right side'
#   Frame 1500: Classified as 'a person looking to the right side'
#   Frame 1515: Classified as 'a person driving normally looking forward'
#   Frame 1530: Classified as 'a person looking to the right side'
#   Frame 1545: Classified as 'a person driving normally looking forward'
#   Frame 1560: Classified as 'a person looking to the right side'
#   Frame 1575: Classified as 'a person looking to the right side'
#   Frame 1590: Classified as 'a person looking to the right side'
#   Frame 1605: Classified as 'a person looking to the right side'
#   Frame 1620: Classified as 'a person looking to the right side'
#   Frame 1635: Classified as 'a person driving normally looking forward'
#   Frame 1650: Classified as 'a person looking to the left side'
#   Frame 1665: Classified as 'a person looking to the right side'
#   Frame 1680: Classified as 'a person looking to the left side'
#   Frame 1695: Classified as 'a person looking to the right side'
#   Frame 1710: Classified as 'a person looking to the right side'
#   Frame 1725: Classified as 'a person looking to the right side'
#   Frame 1740: Classified as 'a person looking to the left side'
#   Frame 1755: Classified as 'a person looking to the right side'
#   Frame 1770: Classified as 'a person looking to the right side'
#   Frame 1785: Classified as 'a person looking to the right side'
#   Frame 1800: Classified as 'a person looking to the right side'
#   Frame 1815: Classified as 'a person looking to the right side'
#   Frame 1830: Classified as 'a person looking to the right side'
#   Frame 1845: Classified as 'a person looking to the right side'
#   Frame 1860: Classified as 'a person looking to the right side'
#   Frame 1875: Classified as 'a person looking to the right side'
#   Frame 1890: Classified as 'a person looking to the right side'
#   Frame 1905: Classified as 'a person looking to the right side'
#   Frame 1920: Classified as 'a person looking to the right side'
#   Frame 1935: Classified as 'a person looking to the right side'
#   Frame 1950: Classified as 'a person looking to the right side'
#   Frame 1965: Classified as 'a person looking to the right side'
#   Frame 1980: Classified as 'a person looking to the right side'
#   Frame 1995: Classified as 'a person looking to the right side'
#   Frame 2010: Classified as 'a person looking to the right side'
#   Frame 2025: Classified as 'a person looking to the right side'
#   Frame 2040: Classified as 'a person looking to the right side'
#   Frame 2055: Classified as 'a person looking to the right side'
#   Frame 2070: Classified as 'a person looking to the right side'
#   Frame 2085: Classified as 'a person looking to the right side'
#   Frame 2100: Classified as 'a person looking to the right side'
#   Frame 2115: Classified as 'a person looking to the right side'
#   Frame 2130: Classified as 'a person looking to the right side'
#   Frame 2145: Classified as 'a person looking to the right side'
#   Frame 2160: Classified as 'a person looking to the right side'
#   Frame 2175: Classified as 'a person looking to the right side'
#   Frame 2190: Classified as 'a person looking to the right side'
#   Frame 2205: Classified as 'a person looking to the right side'
#   Frame 2220: Classified as 'a person looking to the right side'
#   Frame 2235: Classified as 'a person looking to the right side'
#   Frame 2250: Classified as 'a person looking to the right side'
#   Frame 2265: Classified as 'a person looking to the right side'
#   Frame 2280: Classified as 'a person looking to the right side'
#   Frame 2295: Classified as 'a person looking to the right side'
#   Frame 2310: Classified as 'a person looking to the right side'
#   Frame 2325: Classified as 'a person looking to the right side'
#   Frame 2340: Classified as 'a person driving normally looking forward'
#   Frame 2355: Classified as 'a person driving normally looking forward'
#   Frame 2370: Classified as 'a person looking to the right side'
#   Frame 2385: Classified as 'a person looking to the right side'
#   Frame 2400: Classified as 'a person looking to the right side'
#   Frame 2415: Classified as 'a person looking to the right side'
#   Frame 2430: Classified as 'a person looking to the right side'
#   ✅ Finished classifying frames. Now grouping actions and cutting clips...
#     🎬 Cutting clip for 'Looking_Right' (0.00s to 3.50s)
#     🎬 Cutting clip for 'Looking_Right' (4.00s to 14.00s)
#     🎬 Cutting clip for 'Looking_Right' (14.50s to 39.49s)
#     🎬 Cutting clip for 'Looking_Right' (39.99s to 50.49s)
#     🎬 Cutting clip for 'Looking_Right' (51.99s to 54.48s)
#     🎬 Cutting clip for 'Looking_Right' (58.48s to 77.98s)
#     🎬 Cutting final clip for 'Looking_Right' (78.98s to 81.25s)
#
# ▶️ Processing video: VID_20250610_120636997.mp4
#   Frame 0: Classified as 'a person looking to the right side'
#   Frame 15: Classified as 'a person looking to the right side'
#   Frame 30: Classified as 'a person looking to the right side'
#   Frame 45: Classified as 'a person looking to the right side'
#   Frame 60: Classified as 'a person looking to the right side'
#   Frame 75: Classified as 'a person looking to the right side'
#   Frame 90: Classified as 'a person looking to the right side'
#   Frame 105: Classified as 'a person looking to the right side'
#   Frame 120: Classified as 'a person looking to the right side'
#   Frame 135: Classified as 'a person looking to the right side'
#   Frame 150: Classified as 'a person looking to the right side'
#   Frame 165: Classified as 'a person looking to the right side'
#   Frame 180: Classified as 'a person looking to the right side'
#   Frame 195: Classified as 'a person looking to the right side'
#   Frame 210: Classified as 'a person looking to the right side'
#   Frame 225: Classified as 'a person looking to the right side'
#   Frame 240: Classified as 'a person looking to the right side'
#   Frame 255: Classified as 'a person looking to the right side'
#   Frame 270: Classified as 'a person looking to the right side'
#   Frame 285: Classified as 'a person looking to the right side'
#   Frame 300: Classified as 'a person looking to the right side'
#   Frame 315: Classified as 'a person looking to the right side'
#   Frame 330: Classified as 'a person looking to the right side'
#   Frame 345: Classified as 'a person looking to the right side'
#   Frame 360: Classified as 'a person looking to the right side'
#   Frame 375: Classified as 'a person looking to the right side'
#   Frame 390: Classified as 'a person looking to the right side'
#   Frame 405: Classified as 'a person looking to the right side'
#   Frame 420: Classified as 'a person looking to the right side'
#   Frame 435: Classified as 'a person looking to the right side'
#   Frame 450: Classified as 'a person looking to the right side'
#   Frame 465: Classified as 'a person looking to the right side'
#   Frame 480: Classified as 'a person looking to the right side'
#   Frame 495: Classified as 'a person looking to the right side'
#   Frame 510: Classified as 'a person looking to the right side'
#   Frame 525: Classified as 'a person looking to the right side'
#   Frame 540: Classified as 'a person looking to the right side'
#   Frame 555: Classified as 'a person looking to the right side'
#   Frame 570: Classified as 'a person looking to the right side'
#   Frame 585: Classified as 'a person looking to the right side'
#   Frame 600: Classified as 'a person looking to the right side'
#   Frame 615: Classified as 'a person looking to the right side'
#   Frame 630: Classified as 'a person looking to the right side'
#   Frame 645: Classified as 'a person looking to the right side'
#   Frame 660: Classified as 'a person looking to the right side'
#   Frame 675: Classified as 'a person looking to the right side'
#   Frame 690: Classified as 'a person looking to the right side'
#   Frame 705: Classified as 'a person looking to the right side'
#   Frame 720: Classified as 'a person looking to the right side'
#   Frame 735: Classified as 'a person looking to the right side'
#   Frame 750: Classified as 'a person looking to the right side'
#   Frame 765: Classified as 'a person looking to the right side'
#   Frame 780: Classified as 'a person looking to the right side'
#   Frame 795: Classified as 'a person looking to the right side'
#   Frame 810: Classified as 'a person looking to the right side'
#   Frame 825: Classified as 'a person looking to the right side'
#   Frame 840: Classified as 'a person looking to the right side'
#   Frame 855: Classified as 'a person looking to the right side'
#   Frame 870: Classified as 'a person looking to the right side'
#   Frame 885: Classified as 'a person looking to the right side'
#   Frame 900: Classified as 'a person looking to the right side'
#   Frame 915: Classified as 'a person looking to the right side'
#   Frame 930: Classified as 'a person looking to the right side'
#   Frame 945: Classified as 'a person looking to the right side'
#   Frame 960: Classified as 'a person looking to the right side'
#   Frame 975: Classified as 'a person looking to the right side'
#   Frame 990: Classified as 'a person driving normally looking forward'
#   Frame 1005: Classified as 'a person looking to the right side'
#   Frame 1020: Classified as 'a person looking to the right side'
#   Frame 1035: Classified as 'a person looking to the right side'
#   Frame 1050: Classified as 'a person looking to the right side'
#   Frame 1065: Classified as 'a person looking to the right side'
#   Frame 1080: Classified as 'a person looking to the right side'
#   Frame 1095: Classified as 'a person looking to the right side'
#   Frame 1110: Classified as 'a person looking to the right side'
#   Frame 1125: Classified as 'a person looking to the right side'
#   Frame 1140: Classified as 'a person looking to the right side'
#   Frame 1155: Classified as 'a person looking to the right side'
#   Frame 1170: Classified as 'a person looking to the right side'
#   Frame 1185: Classified as 'a person looking to the right side'
#   Frame 1200: Classified as 'a person looking to the right side'
#   Frame 1215: Classified as 'a person looking to the right side'
#   Frame 1230: Classified as 'a person looking to the right side'
#   Frame 1245: Classified as 'a person looking to the right side'
#   Frame 1260: Classified as 'a person looking to the right side'
#   Frame 1275: Classified as 'a person looking to the right side'
#   Frame 1290: Classified as 'a person looking to the right side'
#   Frame 1305: Classified as 'a person looking to the right side'
#   Frame 1320: Classified as 'a person looking to the right side'
#   Frame 1335: Classified as 'a person looking to the right side'
#   Frame 1350: Classified as 'a person looking to the right side'
#   Frame 1365: Classified as 'a person looking to the right side'
#   Frame 1380: Classified as 'a person looking to the right side'
#   Frame 1395: Classified as 'a person looking to the right side'
#   Frame 1410: Classified as 'a person looking to the right side'
#   Frame 1425: Classified as 'a person looking to the right side'
#   Frame 1440: Classified as 'a person looking to the right side'
#   Frame 1455: Classified as 'a person looking to the right side'
#   Frame 1470: Classified as 'a person looking to the right side'
#   Frame 1485: Classified as 'a person looking to the right side'
#   Frame 1500: Classified as 'a person looking to the right side'
#   Frame 1515: Classified as 'a person looking to the right side'
#   Frame 1530: Classified as 'a person looking to the right side'
#   Frame 1545: Classified as 'a person looking to the right side'
#   Frame 1560: Classified as 'a person looking to the right side'
#   Frame 1575: Classified as 'a person looking to the right side'
#   Frame 1590: Classified as 'a person looking to the right side'
#   Frame 1605: Classified as 'a person looking to the right side'
#   Frame 1620: Classified as 'a person looking to the right side'
#   Frame 1635: Classified as 'a person looking to the right side'
#   Frame 1650: Classified as 'a person driving normally looking forward'
#   Frame 1665: Classified as 'a person driving normally looking forward'
#   Frame 1680: Classified as 'a person driving normally looking forward'
#   Frame 1695: Classified as 'a person looking to the right side'
#   Frame 1710: Classified as 'a person looking to the right side'
#   Frame 1725: Classified as 'a person looking to the right side'
#   Frame 1740: Classified as 'a person looking to the right side'
#   Frame 1755: Classified as 'a person looking to the right side'
#   Frame 1770: Classified as 'a person looking to the right side'
#   Frame 1785: Classified as 'a person driving normally looking forward'
#   Frame 1800: Classified as 'a person looking to the right side'
#   Frame 1815: Classified as 'a person looking to the right side'
#   Frame 1830: Classified as 'a person looking to the right side'
#   Frame 1845: Classified as 'a person looking to the right side'
#   Frame 1860: Classified as 'a person looking to the right side'
#   Frame 1875: Classified as 'a person looking to the right side'
#   Frame 1890: Classified as 'a person looking to the right side'
#   Frame 1905: Classified as 'a person looking to the right side'
#   Frame 1920: Classified as 'a person looking to the right side'
#   Frame 1935: Classified as 'a person looking to the right side'
#   Frame 1950: Classified as 'a person looking to the right side'
#   Frame 1965: Classified as 'a person looking to the right side'
#   Frame 1980: Classified as 'a person looking to the right side'
#   Frame 1995: Classified as 'a person driving normally looking forward'
#   Frame 2010: Classified as 'a person looking down at a phone'
#   ✅ Finished classifying frames. Now grouping actions and cutting clips...
#     🎬 Cutting clip for 'Looking_Right' (0.00s to 33.25s)
#     🎬 Cutting clip for 'Looking_Right' (33.75s to 55.41s)
#     🎬 Cutting clip for 'Looking_Right' (56.92s to 59.94s)
#     🎬 Cutting clip for 'Looking_Right' (60.45s to 66.99s)
#
#
# 🎉 All videos processed.
